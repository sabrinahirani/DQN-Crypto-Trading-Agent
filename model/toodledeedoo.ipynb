# %%
import torch
import torch.nn as nn
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import pandas as pd

# Load and combine data from all five stocks
dfs = []
for stock_name in ['./data/BTC-USD-1d', './data/DOGE-USD-1d', './data/ETH-USD-1d', './data/LTC-USD-1d', './data/XRP-USD-1d']:
    df = pd.read_csv(stock_name + '.csv')
    df['stock'] = stock_name  # Add a column to identify the stock
    dfs.append(df)

combined_df = pd.concat(dfs)

# Extract relevant features
features = combined_df[['Close', 'Volume']].values

# # Normalize the data
# scaler = MinMaxScaler(feature_range=(0, 1))
# scaled_data = scaler.fit_transform(features)

# # Convert the data into PyTorch tensors
# tensor_data = torch.Tensor(scaled_data)

# # Define the neural network architecture
# class StockPredictor(nn.Module):
#     def __init__(self, input_size, hidden_size, num_layers, output_size):
#         super(StockPredictor, self).__init__()
#         self.hidden_size = hidden_size
#         self.num_layers = num_layers
#         self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True)
#         self.fc = nn.Linear(hidden_size, output_size)

#     def forward(self, x):
#         h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
#         out, _ = self.rnn(x, h0)
#         out = self.fc(out[:, -1, :])  # Take the output of the last time step
#         return out

# # Set hyperparameters
# input_size = 2  # number of features (Close price and Volume)
# hidden_size = 64  # number of neurons in the hidden layer
# num_layers = 1  # number of RNN layers
# output_size = 1  # number of output neurons (predicted closing price)

# # Initialize the model
# model = StockPredictor(input_size, hidden_size, num_layers, output_size)

# # Define loss function and optimizer
# criterion = nn.MSELoss()
# optimizer = torch.optim.Adam(model.parameters(), lr=0.001)  # You can adjust the learning rate as needed

# # Define training parameters
# num_epochs = 100
# batch_size = 64

# # Split the data into training and testing sets
# train_data, test_data = train_test_split(tensor_data, test_size=0.2, shuffle=False)

# # Train the model
# for epoch in range(num_epochs):
#     for i in range(0, len(train_data), batch_size):
#         batch_x = train_data[i:i+batch_size, :-1].unsqueeze(1)  # Reshape to (batch_size, sequence_length, input_size)
#         batch_y = train_data[i:i+batch_size, -1]

#         # Forward pass
    #     outputs = model(batch_x)
    #     loss = criterion(outputs, batch_y.unsqueeze(1))  # Reshape to (batch_size, output_size)

    #     # Backward pass and optimization
    #     optimizer.zero_grad()
    #     loss.backward()
    #     optimizer.step()

    # if (epoch+1) % 10 == 0:
    #     print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

# # Evaluate the model
# model.eval()
# with torch.no_grad():
#     test_inputs = test_data[:-1, :-1].unsqueeze(1)  # Reshape to (batch_size, sequence_length, input_size)
#     predicted = model(test_inputs).squeeze(1)
#     predicted = scaler.inverse_transform(predicted.unsqueeze(1)).flatten()

# # You can then compare 'predicted' with actual test data to evaluate the performance of your model
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 69
#      66 batch_y = train_data[i:i+batch_size, -1]
#      68 # Forward pass
# ---> 69 outputs = model(batch_x)
#      70 loss = criterion(outputs, batch_y.unsqueeze(1))  # Reshape to (batch_size, output_size)
#      72 # Backward pass and optimization
#
# File c:\Users\sabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\sabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
# ...
